# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file_id = '1IEdyCD99vY44xYEFOFkb0gEYKLufHBaG' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('NMT.zip')

# %%
# !unzip NMT.zip
# Out:
# Archive:  NMT.zip
# replace NMT/prepare_data.sh? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: NMT/prepare_data.sh
#   inflating: NMT/CONTRIBUTING.md
#   inflating: NMT/README.md
#   inflating: NMT/PATENTS
#   inflating: NMT/LICENSE
#   inflating: NMT/fairseq.gif
#  extracting: NMT/requirements.txt
#   inflating: NMT/score.py
#   inflating: NMT/setup.py
#   inflating: NMT/train.py
#   inflating: NMT/preprocess.py
#   inflating: NMT/multiprocessing_train.py
#   inflating: NMT/distributed_train.py
#   inflating: NMT/eval_lm.py
#   inflating: NMT/generate.py
#   inflating: NMT/interactive.py
#   inflating: NMT/preprocess/challenger.py
#   inflating: NMT/preprocess/make_dataset.py
#   inflating: NMT/preprocess/nltk_tokenize.py
#   inflating: NMT/preprocess/prepare.py
#   inflating: NMT/preprocess/tokenizer.py
#   inflating: NMT/preprocess/wmt.py
#   inflating: NMT/fairseq/__init__.py
#   inflating: NMT/fairseq/bleu.py
#   inflating: NMT/fairseq/distributed_utils.py
# ...

# %%
import os
os.chdir('NMT')

# %%
# !pip install -r requirements.txt
# !python setup.py build develop
# !python train.py preprocess/data/data-bin \
    --lr 0.25 --clip-norm 0.1 --dropout 0.2 --max-tokens 4000 \
    --arch lstm --save-dir checkpoints/fconv --max-epoch 25
# Out:
# ...
# running build
# running build_py
# running build_ext
# running develop
# running egg_info
# writing fairseq.egg-info/PKG-INFO
# writing dependency_links to fairseq.egg-info/dependency_links.txt
# writing requirements to fairseq.egg-info/requires.txt
# writing top-level names to fairseq.egg-info/top_level.txt
# reading manifest file 'fairseq.egg-info/SOURCES.txt'
# writing manifest file 'fairseq.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.6/fairseq/libbleu.cpython-36m-x86_64-linux-gnu.so -> fairseq
# Creating /usr/local/lib/python3.6/dist-packages/fairseq.egg-link (link to .)
# fairseq 0.6.0 is already the active version in easy-install.pth
#
# Installed /content/NMT/NMT/NMT
# Processing dependencies for fairseq==0.6.0
# Searching for tqdm==4.28.1
# Best match: tqdm 4.28.1
# Adding tqdm 4.28.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for torch==1.0.0
# ...

# %%
# !python setup.py build develop
# !python interactive.py ./preprocess/data/data-bin --path checkpoints/fconv/checkpoint_best.pt \
  --beam 5
# Out:
# Namespace(beam=5, buffer_size=1, cpu=False, data=['./preprocess/data/data-bin'], diverse_beam_groups=1, diverse_beam_strength=0.5, fp16=False, fp16_init_scale=128, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', left_pad_source='True', left_pad_target='False', lenpen=1, log_format=None, log_interval=1000, max_len_a=0, max_len_b=200, max_sentences=1, max_source_positions=1024, max_target_positions=1024, max_tokens=None, min_len=1, model_overrides='{}', nbest=1, no_beamable_mm=False, no_early_stop=False, no_progress_bar=False, num_shards=1, path='checkpoints/fconv/checkpoint_best.pt', prefix_size=0, print_alignment=False, quiet=False, raw_text=False, remove_bpe=None, replace_unk=None, sampling=False, sampling_temperature=1, sampling_topk=-1, score_reference=False, seed=1, shard_id=0, skip_invalid_size_inputs_valid_test=False, source_lang=None, target_lang=None, task='translation', unkpen=0, unnormalized=False, upsample_primary=1)
# | [hi] dictionary: 32248 types
# ...
